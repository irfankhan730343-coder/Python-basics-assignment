# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
# write your answer here
tup1=(1,2,3,4,5)
print(tup1)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
# write your answer here
tup1="irfan",24,4.2,True
print(tup1)
# Out:
# ('irfan', 24, 4.2, True)

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
# write your answer here
student="irfan","jaswant","rohit","sekhar"
print(len(student))
# Out:
# 4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
# write your answer here
student="irfan","jaswant","rohit","sekhar"
print(student[-1])
# Out:
# sekhar

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
# write your answer here
student="irfan","jaswant","rohit","sekhar"
print("irfan" in student)
# Out:
# True

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
# write your answer here
student="irfan","jaswant","rohit","sekhar"
print(list(student))
# Out:
# ['irfan', 'jaswant', 'rohit', 'sekhar']

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
# write your answer here
student=["irfan","jaswant","rohit","sekhar"]
print(tuple(student))
# Out:
# ('irfan', 'jaswant', 'rohit', 'sekhar')

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
# write your answer here
student=("irfan","jaswant","rohit","sekhar","irfan")
print(student.count("irfan"))
# Out:
# 2

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
# write your answer here
student=("irfan","jaswant","rohit","sekhar","jaswant2")
print(student.index("jaswant2"))
# Out:
# 4

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
# write your answer here
student=("irfan","jaswant","rohit","sekhar")
student[0]="jaswant" # this line thro error enchance to change

#yes tupple is immutable (cannot be changed)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2092998969.py in <cell line: 0>()
#       1 # write your answer here
#       2 student=("irfan","jaswant","rohit","sekhar")
# ----> 3 student[0]="jaswant"
#
# TypeError: 'tuple' object does not support item assignment
